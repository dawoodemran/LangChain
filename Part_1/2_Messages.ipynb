# %% [markdown]
# **Messages**

# %%
ensure_openrouter_reachable()

my_messages = [
    SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="Bro, tell me a fun fact"),
]

invoke_openrouter(my_messages)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ensure_openrouter_reachable()
#       2
#       3 my_messages = [
#       4     SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
#
# Cell In[9], line 22, in ensure_openrouter_reachable()
#      19 def ensure_openrouter_reachable() -> None:
#      20     response = httpx.get(f"{openrouter_api_base.rstrip('/')}/models", timeout=15.0)
#      21     if response.status_code == 403 and "security policy" in response.text.lower():
# ---> 22         raise RuntimeError(
#      23             "OpenRouter is blocked from your network (403 security policy). "
#      24             "Use a VPN/proxy in a supported region, then rerun this cell."
#      25         )
#
# RuntimeError: OpenRouter is blocked from your network (403 security policy). Use a VPN/proxy in a supported region, then rerun this cell.
