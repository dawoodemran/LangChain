# %% [markdown]
# **Messages**

# %%
import os
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_openrouter import ChatOpenRouter

llm_openrouter = ChatOpenRouter(model="openai/gpt-4o-mini", temperature=0)

my_messages = [
    SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="Bro, tell me a fun fact"),
]

llm_openrouter.invoke(my_messages).content
# Out:
# 'Yo, did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly good to eat! Talk about a sweet time capsule! 🍯✨'

# %% [markdown]
# Prompts

# %%
from langchain_openrouter  import ChatOpenRouter
from langchain_core.messages import SystemMessage, HumanMessage

llm_anthropic = ChatOpenRouter(
    model="openai/gpt-4o-mini"
)
my_messages = [
    SystemMessage(
        content="You are a gen-z assistant"
    ),
    HumanMessage(
        content="Bro, tell me a fun fact about Honey"
    )
]
response = llm_openrouter.invoke(my_messages)
print(response.content)
# Out:
# Yo, did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible! It's all thanks to its low moisture content and acidic pH, which create a super unfriendly environment for bacteria. Sweet, right? 🍯✨

# %%
from langchain_core.prompts import PromptTemplate

user_input = input("Enter a topic for fun fact : ")

dynamic_prompt = PromptTemplate.from_template("Write a fun fact about {topic}")

ready_prompt = dynamic_prompt.invoke({"topic" : user_input})

llm_openrouter.invoke(ready_prompt).content
# Out:
# "Sure! Here’s a fun fact: Honey never spoils! Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible. This is due to honey's low moisture content and acidic pH, which create an inhospitable environment for bacteria and microorganisms. So, if you have a jar of honey sitting in your pantry, it could last indefinitely!"

# %%
from langchain_core.prompts import ChatPromptTemplate 

prompt_template = ChatPromptTemplate.from_messages([
    ("system","You are a {tone} assistant"),
    ("user","Write a fun fact about {topic}.")
])

user_input = input("Enter a topic: ")
user_tone = input("Enter a tone: ")

ready_prompt = prompt_template.invoke({"topic":user_input,"tone":user_tone})

llm_openrouter.invoke(ready_prompt.messages)
