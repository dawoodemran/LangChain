# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

load_dotenv()

if os.environ.get("OPENROUTER_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENROUTER_API_KEY not found")

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenRouter(model="openai/gpt-4o-mini", temperature=0)
# Out:
# Bro API KEY Variable exists

# %%
# TASK - 1 [Prompt]

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("human", "{input}")
])

# %%
# TASK - 2 [LLM]

llm = ChatOpenRouter(model="openai/gpt-4o-mini", temperature=0)

# %%
# TASK - 3 [Str Parser]

str_parser = StrOutputParser()

# %%
# TASK - 4 [Custom Runnable]
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text: str) -> dict:
    return {"text": text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %%
# TASK - 5 [Template For Post]

prompt_post = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "You're a social media post generator."),
        ("human", "Create a post for the following text for LinkedIn: {text}"),
    ]
)

# %%
# TASK - 5 [Template For Post]

prompt_post = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "You're a social media post generator."),
        ("human", "Create a post for the following text for LinkedIn: {text}"),
    ]
)

# %%
# TASK - 7 [Str Parser]

str_parser = StrOutputParser()

# %%
# CHAIN

chain = prompt_template | llm | str_parser | dictionary_maker_runnable | prompt_post | llm | str_parser

chain.invoke({"input": "What is the capital of France?"})
# Out:
# "🌍 Did you know? The capital of France is none other than the iconic city of Paris! 🇫🇷✨ Known for its rich history, stunning architecture, and vibrant culture, Paris is a hub for innovation and creativity. Whether you're exploring the Louvre, strolling along the Seine, or enjoying a café in Montmartre, there's always something new to discover. \n\nWhat’s your favorite memory or experience in Paris? Share in the comments! 👇 #Paris #France #Travel #Culture #Innovation"
